# %%
from aip import AipBodyAnalysis
import cv2
import time
from PIL import Image  
import os
import threading

# %%
def get_file_content(filePath):
    with open(filePath,'rb') as fp:
        return fp.read()
    


def style_transfer(model,
                    img,
                   pathOut='',
                   width=None,
                   jpg_quality=80,
                    ):
    ## 从本地加载预训练模型
    print('加载预训练模型......')
    #print(pathIn)
    ## 读入原始图片，调整图片至所需尺寸，然后获取图片的宽度和高度
    #img = cv2.imread(pathIn)
    (h, w) = img.shape[:2]
    if width is not None:
        img = cv2.resize(img, (width, round(width*h/w)), interpolation=cv2.INTER_CUBIC)
        (h, w) = img.shape[:2]

    ## 将图片构建成一个blob：设置图片尺寸，将各通道像素值减去平均值（比如ImageNet所有训练样本各通道统计平均值）
    ## 然后执行一次前馈网络计算，并输出计算所需的时间
    blob = cv2.dnn.blobFromImage(img, 1.0, (w, h), (103.939, 116.779, 123.680), swapRB=False, crop=False)
    model.setInput(blob)
    start = time.time()
    output = model.forward()
    end = time.time()
    print("风格迁移花费：{:.2f}秒".format(end - start))

    ## reshape输出结果, 将减去的平均值加回来，并交换各颜色通道
    output = output.reshape((3, output.shape[2], output.shape[3]))
    output[0] += 103.939
    output[1] += 116.779
    output[2] += 123.680
    output = output.transpose(1, 2, 0)
    ## 输出风格化后的图片
    cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])

def get_model(rootdir):
    list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
    models=[]
    for i in list:
        i = rootdir+'/'+i
        model = cv2.dnn.readNetFromTorch(i)
        models.append(model)
    
    return models   

def get_pic(rootdir):
    list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
    pics=[]
    for i in list:
        i = rootdir+'/'+i
        pics.append(i)
    
    return pics   

def get_finger_num():
    print('a')
    img=get_file_content('a.jpg')
    #print(img)
    a=client.gesture(img)
    if(len(a)==3):
        if(a['result']!=[]):
            if (a['result'][0]['classname']=='Fist'):
                print('ok1')
                return 0
            if (a['result'][0]['classname']=='One'):
                print('ok2')
                return 1
            if (a['result'][0]['classname']=='Two'):
                print('ok3')
                return 2
            if (a['result'][0]['classname']=='Three' or a['result'][0]['classname']=='Ok'):
                print('ok4')
                return 3
            if (a['result'][0]['classname']=='Four'):
                print('ok5')
                return 4
            if (a['result'][0]['classname']=='Five'):
                print('ok6')
                return 5

# %%
API_ID = '17377687'                                    #新的
API_KEY = 'yZKK9Qyi8VphSjq0cdUZ0bqm'
SECRET_KEY = 'KfScBXN8AaQuGhkY7ZHYZE1bvQ7Xk7Me'
client = AipBodyAnalysis(API_ID,API_KEY,SECRET_KEY)  # 建立连接  
models=get_model('D:\jupyter\homework\model')

# %%
pic_flag=0
show_flag=0
finger_flag=0
camera_frame1=[None]
cv2.namedWindow("lalal",cv2.WINDOW_NORMAL)
camera = cv2.VideoCapture(0)
#camera1 = cv2.VideoCapture(1)
img=cv2.imread('D:\jupyter\homework\data/shuai.jpg')
while 1:
    if finger_flag==1:
        finger_flag=0
        print('1')
        finger_num=get_finger_num()
        if finger_num==0:
            break
        if finger_num==5:
            pic_flag=1
        if finger_num==2:
            show_flag=1
            
    if pic_flag==1:
        pic_flag=0
        show_flag=1
        for model in models:
            a=int(time.time())
            pathOut="D:\jupyter\homework\save/"+str(a)+'.jpg'
            output=style_transfer(model,camera_frame1[0],pathOut)
                
    if show_flag==1:
        show_flag=0
        pic_paths=get_pic('D:\jupyter\homework\save')
        print(pic_paths)
        for i in range(len(pic_paths)):
            b=(i+1)%len(pic_paths)
            frame1=cv2.imread(pic_paths[i])
            frame2=cv2.imread(pic_paths[b])
            img[0:479,0:639] = frame1[0:479,0:639]
            img[0:479,640:1279]= frame2[0:479,0:639]
            cv2.imshow('lalal',img)
            k=cv2.waitKey(1000)
                       
    if camera.isOpened():
        ret1, frame1= camera.read()
        camera_frame1[0]=frame1
        #ret2,frame2 = camera1.read()
        cv2.imwrite('a.jpg',frame1)
        img[0:479,0:639] = frame1[0:479,0:639]
        img[0:479,640:1279]= frame1[0:479,0:639]
        #img[0:479,640:1279]= frame2[0:479,0:639]
        cv2.imshow('lalal',img)
        k=cv2.waitKey(10)
        if k == 27:
            finger_flag=1

camera.release()
cv2.destroyAllWindows()
# Out:
# 1
# a
# ok6
# 加载预训练模型......
# 风格迁移花费：0.69秒
# 加载预训练模型......
# 风格迁移花费：0.68秒
# 加载预训练模型......
# 风格迁移花费：0.69秒
# 加载预训练模型......
# 风格迁移花费：0.70秒
# 加载预训练模型......
# 风格迁移花费：0.70秒
# 加载预训练模型......
# 风格迁移花费：0.68秒
# 加载预训练模型......
# 风格迁移花费：0.67秒
# ['D:\\jupyter\\homework\\save/1571194309.jpg', 'D:\\jupyter\\homework\\save/1571194310.jpg', 'D:\\jupyter\\homework\\save/1571194311.jpg', 'D:\\jupyter\\homework\\save/1571194312.jpg', 'D:\\jupyter\\homework\\save/1571194313.jpg', 'D:\\jupyter\\homework\\save/1571194314.jpg', 'D:\\jupyter\\homework\\save/1571194453.jpg', 'D:\\jupyter\\homework\\save/1571194454.jpg', 'D:\\jupyter\\homework\\save/1571194455.jpg', 'D:\\jupyter\\homework\\save/1571194456.jpg', 'D:\\jupyter\\homework\\save/1571194457.jpg', 'D:\\jupyter\\homework\\save/1571194458.jpg']
# 1
# a
# ok1
