# %%
from aip import AipBodyAnalysis
import cv2
import time
from PIL import Image  
import os

# %%
def get_file_content(filePath):
    with open(filePath,'rb') as fp:
        return fp.read()
    
def finger():  
    while camera.isOpened():
        ret, frame = camera.read()
        cv2.imwrite('a.jpg',frame)
        #cv2.imshow('lalala',frame)
        img=get_file_content('a.jpg')
        a=client.gesture(img)
        if(len(a)==3 ):
            if(a['result']!=[]):
                #print(a)
                #print(a['result'][0]['classname'])
                if (a['result'][0]['classname']=='Fist'):
                    return 0
                if (a['result'][0]['classname']=='One'):
                     return 1
                if (a['result'][0]['classname']=='Two'):
                     return 2
                if (a['result'][0]['classname']=='Three' or a['result'][0]['classname']=='Ok'):
                    return 3
                if (a['result'][0]['classname']=='Four'):
                     return 4
                if (a['result'][0]['classname']=='Five'):
                     return 5

def style_transfer(model,
                    img,
                   pathOut='',
                   width=None,
                   jpg_quality=80,
                    ):
    ## 从本地加载预训练模型
    print('加载预训练模型......')
    #print(pathIn)
    ## 读入原始图片，调整图片至所需尺寸，然后获取图片的宽度和高度
    #img = cv2.imread(pathIn)
    (h, w) = img.shape[:2]
    if width is not None:
        img = cv2.resize(img, (width, round(width*h/w)), interpolation=cv2.INTER_CUBIC)
        (h, w) = img.shape[:2]

    ## 将图片构建成一个blob：设置图片尺寸，将各通道像素值减去平均值（比如ImageNet所有训练样本各通道统计平均值）
    ## 然后执行一次前馈网络计算，并输出计算所需的时间
    blob = cv2.dnn.blobFromImage(img, 1.0, (w, h), (103.939, 116.779, 123.680), swapRB=False, crop=False)
    model.setInput(blob)
    start = time.time()
    output = model.forward()
    end = time.time()
    print("风格迁移花费：{:.2f}秒".format(end - start))

    ## reshape输出结果, 将减去的平均值加回来，并交换各颜色通道
    output = output.reshape((3, output.shape[2], output.shape[3]))
    output[0] += 103.939
    output[1] += 116.779
    output[2] += 123.680
    output = output.transpose(1, 2, 0)
    return output
    ## 输出风格化后的图片
    cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])

def model_path(rootdir):
    list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
    path=[]
    for i in list:
        i = rootdir+'/'+i
        path.append(i)
    return path

def change_styles():
    model_num=(model_num+1)%7
    model_path=paths[model_num]

    
def show_pic(path):
    frame=cv2.imread(path)
    #print(frame,1)
    cv2.imshow('lalal',frame)
    #cv2.waitKey(0)
    
def two_cameras():

# %%
import numpy
import cv2
cv2.namedWindow("lalal",cv2.WINDOW_NORMAL)
#cv2.namedWindow('lalal', cv2.WINDOW_FREERATIO)
camera = cv2.VideoCapture(0)
img=cv2.imread('D:\jupyter\homework\save/lll.jpg')
while camera.isOpened():
    ret, frame1 = camera.read()
    #frame1=cv2.imread('D:\jupyter\homework\save/1.jpg')
    #frame2=cv2.imread('D:\jupyter\homework\save/2.jpg')
    img[0:479,0:639] = frame1[0:479,0:639]
    #model = cv2.dnn.readNetFromTorch(paths[i])
    #pathOut="D:\jupyter\homework\save/"+str(output_num)+'.jpg'
    #output=style_transfer(model,frame1,pathOut)
    #img[0:479,640:1279]= frame2[0:479,0:639]
    a=finger()
    print(a)
    cv2.imshow('lalal',img)
    cv2.waitKey(10)
# Out:
# 1
# 1
# 1
# 1
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
# ...

# %%
API_ID = '17377687'                                    #新的
API_KEY = 'yZKK9Qyi8VphSjq0cdUZ0bqm'
SECRET_KEY = 'KfScBXN8AaQuGhkY7ZHYZE1bvQ7Xk7Me'
client = AipBodyAnalysis(API_ID,API_KEY,SECRET_KEY)  # 建立连接  
cv2.namedWindow("lalal",cv2.WINDOW_NORMAL)
camera = cv2.VideoCapture(0)   #打开电脑自带摄像头，如果参数是1会打开外接摄像头
#help(camera)
camera.set(10, 200)   #设置视频属性
rootdir = 'D:\jupyter\homework\model'
paths=model_path(rootdir)
i=6
steps=[1,0,0,0,0]
get_pic=1
output_num=1
pic=None
finger_num=[None,None,None]
while 1:
    #show_pic('D:\jupyter\homework\data/1.jpg')
    #im = Image.open('D:\jupyter\homework\data/1.jpg')  ##文件存在的路径
    #im.show()
    print("Please select 1")
    finger_num[0]=finger()
    time.sleep(2)
    print('The num of finger1 is:',finger_num[0])
    if finger_num[0]==1:
        while 1:
            #show_pic('D:\jupyter\homework\data/1.jpg')
            if get_pic==1:
                print("please get a pic")
                finger_num_get=finger()
                if(finger_num_get!=None):
                    ret, pic = camera.read()
                    get_pic=0
            print("please select 2")
            finger_num[1]=finger()
            print(finger_num[1])
            if finger_num[1]==1:
                i=(i+1)%7
                #show_pic('D:\jupyter\homework\data/1.jpg')
                model = cv2.dnn.readNetFromTorch(paths[i])
                pathOut="D:\jupyter\homework\save/"+str(output_num)+'.jpg'
                output=style_transfer(model,pic,pathOut)
                
                output_num=output_num+1
                #cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])
            if finger_num[1]==2:
                i=(i-1)%7
                #show_pic('D:\jupyter\homework\data/1.jpg')
                model = cv2.dnn.readNetFromTorch(paths[i])
                pathOut="D:\jupyter\homework\save/"+str(output_num)+'.jpg'
                style_transfer(model,pic,pathOut)
                output_num=output_num+1
               # cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])
            if finger_num[1]==0:
                break
            if finger_num[1]==5:
                get_pic=1
                
                
    if finger_num[0]==2:
        rootdir = 'D:\jupyter\homework\model'
        pic_paths=model_path(rootdir)
        
camera.release()
cv2.destroyAllWindows()
# Out:
# Please select 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ...

# %%
API_ID = '17377687'                                    #原来的
API_KEY = 'yZKK9Qyi8VphSjq0cdUZ0bqm'
SECRET_KEY = 'KfScBXN8AaQuGhkY7ZHYZE1bvQ7Xk7Me'
client = AipBodyAnalysis(API_ID,API_KEY,SECRET_KEY)  # 建立连接  
cv2.namedWindow('lalal', cv2.WINDOW_AUTOSIZE)
camera = cv2.VideoCapture(0)   #打开电脑自带摄像头，如果参数是1会打开外接摄像头
#help(camera)
camera.set(10, 200)   #设置视频属性
rootdir = 'D:\jupyter\homework\model'
paths=model_path(rootdir)
i=6
steps=[1,0,0,0,0]
get_pic=1
output_num=1
pic=None
finger_num=[None,None,None]
while 1:
    #show_pic('D:\jupyter\homework\data/1.jpg')
    #im = Image.open('D:\jupyter\homework\data/1.jpg')  ##文件存在的路径
    #im.show()
    print("Please select 1")
    finger_num[0]=finger()
    time.sleep(2)
    print('The num of finger1 is:',finger_num[0])
    if finger_num[0]==1:
        while 1:
            #show_pic('D:\jupyter\homework\data/1.jpg')
            if get_pic==1:
                print("please get a pic")
                finger_num_get=finger()
                if(finger_num_get!=None):
                    ret, pic = camera.read()
                    get_pic=0
            print("please select 2")
            finger_num[1]=finger()
            print(finger_num[1])
            if finger_num[1]==1:
                i=(i+1)%7
                #show_pic('D:\jupyter\homework\data/1.jpg')
                model = cv2.dnn.readNetFromTorch(paths[i])
                pathOut="D:\jupyter\homework\save/"+str(output_num)+'.jpg'
                output=style_transfer(model,pic,pathOut)
                
                output_num=output_num+1
                cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])
            if finger_num[1]==2:
                i=(i-1)%7
                #show_pic('D:\jupyter\homework\data/1.jpg')
                model = cv2.dnn.readNetFromTorch(paths[i])
                pathOut="D:\jupyter\homework\save/"+str(output_num)+'.jpg'
                style_transfer(model,pic,pathOut)
                output_num=output_num+1
               # cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])
            if finger_num[1]==0:
                break
            if finger_num[1]==5:
                get_pic=1
                
                
    if finger_num[0]==2:
        rootdir = 'D:\jupyter\homework\model'
        pic_paths=model_path(rootdir)
        
camera.release()
cv2.destroyAllWindows()
# Out:
# Please select 1
# The num of finger1 is: 1
# please get a pic
# please select 2
# 1
# 加载预训练模型......
# 风格迁移花费：0.68秒
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0bf133159cfa> in <module>
#      43
#      44                 output_num=output_num+1
# ---> 45                 cv2.imwrite(pathOut, output, [int(cv2.IMWRITE_JPEG_QUALITY), jpg_quality])
#      46             if finger_num[1]==2:
#      47                 i=(i-1)%7
#
# NameError: name 'jpg_quality' is not defined

# %%
camera.release()
cv2.destroyAllWindows()
